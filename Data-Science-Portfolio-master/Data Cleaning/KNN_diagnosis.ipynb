# %% [markdown]
#    # Cancer Prediction Case Study

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import scale
import sklearn as sk

# %%
data = pd.read_csv('E:\\New Volume\\Downloads\\wbcd.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0         13.50          15.64            86.97       549.1            0.1385
# 1         11.88          22.94            78.28       424.8            0.1213
# 2         12.41          26.44            79.93       471.4            0.1369
# 3         11.92          15.77            76.53       434.0            0.1367
# 4         16.20          15.73           104.50       819.1            0.1126
#
#    compactness_worst  concavity_worst  points_worst  symmetry_worst  \
# 0             0.1266          0.12420       0.09391          0.2827
# 1             0.2515          0.19160       0.07926          0.2940
# 2             0.1482          0.10670       0.07431          0.2998
# 3             0.1822          0.08669       0.08611          0.2102
# 4             0.1737          0.13620       0.08178          0.2487
#
#    dimension_worst
# 0          0.06771
# 1          0.07587
# 2          0.07881
# 3          0.06784
# 4          0.06766
#
# [5 rows x 32 columns]

# %%
data.shape
# Out:
# (569, 32)

# %%
data.isnull().sum()
# Out:
# id                   0
# diagnosis            0
# radius_mean          0
# texture_mean         0
# perimeter_mean       0
# area_mean            0
# smoothness_mean      0
# compactness_mean     0
# concavity_mean       0
# points_mean          0
# symmetry_mean        0
# dimension_mean       0
# radius_se            0
# texture_se           0
# perimeter_se         0
# area_se              0
# smoothness_se        0
# compactness_se       0
# concavity_se         0
# points_se            0
# symmetry_se          0
# dimension_se         0
# radius_worst         0
# texture_worst        0
# perimeter_worst      0
# area_worst           0
# smoothness_worst     0
# compactness_worst    0
# concavity_worst      0
# points_worst         0
# symmetry_worst       0
# dimension_worst      0
# dtype: int64

# %%
X = data.loc[:,['radius_mean','area_mean','smoothness_mean']]
y = data.loc[:,'diagnosis']

# %%
X.head()
# Out:
#    radius_mean  area_mean  smoothness_mean
# 0        12.32      464.1          0.10280
# 1        10.60      346.4          0.09688
# 2        11.04      373.2          0.10770
# 3        11.28      384.8          0.11640
# 4        15.19      711.8          0.07963

# %%
y.head()
# Out:
# 0    B
# 1    B
# 2    B
# 3    B
# 4    B
# Name: diagnosis, dtype: object

# %%
X = scale(X)
X = pd.DataFrame(X)
#X.head()
type(X)
X
# Out:
#             0         1         2
# 0   -0.513297 -0.542624  0.458285
columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30)

# %%
X_train
# Out:
#             0         1         2
# 395 -0.070234 -0.165780 -1.857438
# 328 -0.320167 -0.385345  1.219756
# 95   0.540396  0.393370 -0.103210
# 108 -0.939318 -0.834144 -1.027649
# 363 -1.098366 -0.947908  0.256176
# 229 -0.817192 -0.753372 -0.946520
# 32   0.986298  0.926071 -0.246964
# 402  1.460602  1.442275 -0.167259
# 33  -0.527497 -0.536936 -0.676803
# 143  0.034851 -0.026135  0.607733
# 339  0.455192  0.262542  0.565034
# 364 -0.553058 -0.579597  0.579267
# 535 -0.368449 -0.420896 -0.424166
# 426 -0.618382 -0.648993  1.383436
# 93  -0.320167 -0.383070 -0.901686
# 306  0.310345  0.176365  0.600616
# 437 -0.345728 -0.393877 -1.206274
# 387 -1.033042 -0.911788  0.742947
# 388 -0.146918 -0.205313 -0.105345
# 141  1.097064  0.984375  1.568466
# 355 -1.324157 -1.096371  0.572150
# 284  0.869853  0.777609  0.064029
# 212  0.872693  0.780737  0.764297
# 175 -0.359929 -0.422603  0.212053
# 393  1.429361  1.374017  0.401353
# 308  0.233661  0.098437 -1.066078
# 419 -0.660984 -0.633919  0.906628
# 250  0.259222  0.098153  0.175759
# 230 -0.709266 -0.681985 -0.198572
# 562  0.077453 -0.024997 -1.879499
# ..        ...       ...       ...
# 43  -0.323007 -0.399850 -0.123848
# 400 -1.215664 -1.028681 -0.102498
# 359 -1.361647 -1.111729 -0.281835
# 510 -0.297446 -0.383638  0.792763
# 346 -1.490873 -1.177143 -0.955772
# 154  0.080293 -0.011061 -0.625564
# 295  2.982918  3.373421  0.472519
# 441 -0.144078 -0.232332 -0.277565
# 279 -1.817206 -1.354046 -1.094545
# 222  1.534446  1.598701  1.326504
# 114 -0.672344 -0.645580 -0.710963
# 495 -0.354249 -0.460145  1.810429
# 523 -1.808401 -1.347789 -3.112085
# 199 -0.544538 -0.548596 -1.087428
# 151 -1.245485 -1.038635  0.792763
# 436  1.329956  1.271629 -0.507430
# 6   -0.743348 -0.714976 -0.266890
# 503 -1.010321 -0.900412 -0.400681
# 256  0.114375  0.013683 -0.888165
# 252 -0.811511 -0.747684 -0.904533
# 196  0.270583  0.175512  0.429819
# 323 -0.624062 -0.615148  0.093918
# 31  -0.385490 -0.422603 -0.413491
# 418  1.724735  1.647051  0.191415
# 491  1.838341  1.735218  1.525767
# 440 -0.325847 -0.400703 -0.040584
# 427  0.208100  0.053500 -0.506718
# 397  0.352947  0.208504 -0.310301
# 249 -0.604181 -0.604056 -0.853294
# 97  -0.646783 -0.631929 -0.899551
#
# [398 rows x 3 columns]

# %%
model_knn = KNeighborsClassifier(n_neighbors = 20, metric='euclidean')

model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#                      weights='uniform')

# %%
pv = model_knn.predict(X_test)
np.mean(pv == y_test)
# Out:
# 0.9298245614035088

# %%
accuracy_score(pv,y_test)
confusion_matrix(y_test,pv)
# Out:
# array([[103,  10],
#        [  4,  54]], dtype=int64)

# %%
157/171
# Out:
# 0.9181286549707602

# %%
y_test.shape
# Out:
# (143,)
